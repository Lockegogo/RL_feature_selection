# %%
import pandas as pd

# %%
feature = pd.read_table('1.txt',sep='\t', header= None)
feature
# Out:
#                              0
# 0                       'age',
# 1                        '体温',
# 2                      '呕吐频次',
# 3                      '持续天数',
# 4                       '腹泻量',
# ..                         ...
# 377         '采样类型_腹泻病采样,其他采样',
# 378        '采样类型_腹泻病采样,平行样采样',
# 379   '采样类型_腹泻病采样,平行样采样,其他采样',
# 380              '采样类型_食源性采样',
# 381          '采样类型_食源性采样,其他采样'
#
# [382 rows x 1 columns]

# %%
number = pd.read_table('2.txt',sep=',',header=None).values.tolist()
number = number[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\LOCKEG~1\AppData\Local\Temp/ipykernel_50948/1364526120.py in <module>
#       1 number = pd.read_table('2.txt',sep=',',header=None).values.tolist()
#       2 number = number[0]
# ----> 3 feature[number]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# ...

# %%
feature.iloc[number].values
# Out:
# array([["'age',"],
#        [" '体温',"],
#        [" '腹泻频次',"],
#        [" '疑似病例人数',"],
#        [" '区县_奉贤区',"],
#        [" '区县_宝山区',"],
#        [" '区县_崇明区',"],
#        [" '区县_普陀区',"],
#        [" '区县_杨浦区',"],
#        [" '区县_松江区',"],
#        [" '区县_浦东新区',"],
#        [" '区县_金山区',"],
#        [" '区县_长宁区',"],
#        [" '区县_闵行区',"],
#        [" '区县_闸北区',"],
#        [" '区县_青浦区',"],
#        [" '区县_静安区',"],
#        [" '区县_黄浦区',"],
#        [" '户籍_本市常住',"],
#        [" '户籍_流动人口',"],
#        [" '户籍_流动人口（含港澳台）',"],
#        [" '职业_保育员及保姆',"],
#        [" '职业_其他学生',"],
#        [" '职业_医务人员',"],
#        [" '职业_干部职员',"],
#        [" '职业_无',"],
#        [" '职业_民工',"],
#        [" '职业_海员及长途驾驶员',"],
#        [" '职业_渔(船)民',"],
#        [" '职业_离退人员',"],
#        [" '首发症状_发热',"],
#        [" '首发症状_发热,腹痛',"],
#        [" '首发症状_腹泻',"],
#        [" '首发症状_腹痛',"],
#        [" '发热_有',"],
#        [" '脱水_轻度',"],
#        [" '恶心_有',"],
#        [" '肠鸣音亢进_有',"],
#        [" '腹痛_有',"],
# ...
